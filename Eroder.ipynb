# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from prepare import blockmap
from erode import single_drop
from random import randint

# %%
height_map = mpimg.imread('base.png')
#height_map = blockmap()
for epoch in range(10000):
    amount_map = np.zeros(height_map.shape[:2], dtype=np.float32)
    for drops in range(10):
        x = randint(0, height_map.shape[0] - 1)
        y = randint(0, height_map.shape[1] - 1)
        height_map, amount_map = single_drop(x, y, height_map, amount_map)
fig, ax = plt.subplots(figsize=(20, 10))
ax.imshow(height_map)
